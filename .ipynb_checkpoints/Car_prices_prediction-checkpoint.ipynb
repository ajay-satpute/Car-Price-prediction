# %% [markdown]
# # <span style="color:blue" >Car_prices_Assignment</span>
#
# ## Problem Statement :
# A Chinese automobile company Geely Auto aspires to enter the US market by setting up their manufacturing unit there and producing cars locally to give competition to their US and European counterparts.
#
# Specifically, they want to understand the factors affecting the pricing of cars in the American market, since those may be very different from the Chinese market. The company wants to know:
#    - Which variables are significant in predicting the price of a car
#    - How well those variables describe the price of a car
# Based on various market surveys, the consulting firm has gathered a large dataset of different types of cars across the Americal market.
#
# ## Business Goal :
#
# We are required to model the price of cars with the available independent variables. It will be used by the management to understand how exactly the prices vary with the independent variables. They can accordingly manipulate the design of the cars, the business strategy etc. to meet certain price levels. Further, the model will be a good way for management to understand the pricing dynamics of a new market.

# %% [markdown]
# ## Step 1: Reading and Understanding the Data

# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# %%
# Importing numpy and pandas

import numpy as np
import pandas as pd

# %%
# Loading CarPrice_Assignment.csv file

car_price = pd.read_csv("CarPrice_Assignment.csv",encoding='ISO-8859-10')

# %%
# Now lets look at the dataset
car_price.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
car_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
# car_ID              205 non-null int64
# symboling           205 non-null int64
# CarName             205 non-null object
# fueltype            205 non-null object
# aspiration          205 non-null object
# doornumber          205 non-null object
# carbody             205 non-null object
# drivewheel          205 non-null object
# enginelocation      205 non-null object
# wheelbase           205 non-null float64
# carlength           205 non-null float64
# carwidth            205 non-null float64
# carheight           205 non-null float64
# curbweight          205 non-null int64
# enginetype          205 non-null object
# cylindernumber      205 non-null object
# enginesize          205 non-null int64
# fuelsystem          205 non-null object
# boreratio           205 non-null float64
# stroke              205 non-null float64
# compressionratio    205 non-null float64
# ...

# %% [markdown]
# This tells us that our dataset has 205 rows and 26 columns with no missing values.

# %%
# Lets look at the summary of numerical columns

car_price.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %% [markdown]
# ## Step 2: Visualising the Data

# %%
# Importing required libraries for data visualisation.

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Plotting frequency distribution of 'price' of cars

fig = plt.figure()
car_price[['price']].plot(kind='hist',bins=8,rwidth=0.8)
plt.xlabel('price')
plt.show()

# %% [markdown]
# <font color='red'>**So this suggests that our dataset has more cars with price less than 20000.**</font>

# %% [markdown]
# ### <font color='blue'> Univariate analysis:</font>

# %% [markdown]
# #### Visualising Numeric Variables
#
# Let's make plots of price against all the numeric variables

# %%
# Plotting price vs symboling
plt.figure(figsize=[10,8])
sns.boxplot(x = 'symboling', y = 'price', data = car_price)

# %% [markdown]
# <font color='red'>**The above plot shows that symboling of -1 and -2 have high price of cars. But symboling 3 also has same price range to that of symboling -2.**</font>

# %%
# Subsetting only the numerical columns for plotting
curr = car_price[["wheelbase", "carlength", 'carwidth', "carheight", "curbweight", "enginesize","boreratio","stroke", 
                  "compressionratio", "horsepower", "peakrpm", "citympg", "highwaympg"]]
cor = round(curr.corr(),2)

# figure size
plt.figure(figsize=(12,8))

# heatmap
ax = sns.heatmap(cor, cmap="YlGnBu", annot=True)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()

# %% [markdown]
# <font color='red'>**The above plot shows that `citympg` and `highwaympg` are very correlated. Also `wheelbase` and `carlength` and `curbweight` and `carwidth` are also highly correlated.**</font>

# %%
# Plotting scatter plots
plt.figure(figsize=(20, 12))

plt.subplot(2,3,1)
plt.scatter(car_price.wheelbase,car_price.price)
plt.xlabel('wheelbase')                          
plt.ylabel('price') 

plt.subplot(2,3,2)
plt.scatter(car_price.carlength,car_price.price)
plt.xlabel('carlength')                          
plt.ylabel('price') 

plt.subplot(2,3,3)
plt.scatter(car_price.carwidth,car_price.price)
plt.xlabel('carwidth')                          
plt.ylabel('price') 

plt.subplot(2,3,4)
plt.scatter(car_price.carheight,car_price.price)
plt.xlabel('carheight')                          
plt.ylabel('price') 

plt.subplot(2,3,5)
plt.scatter(car_price.curbweight,car_price.price)
plt.xlabel('curbweight')                          
plt.ylabel('price') 

plt.subplot(2,3,6)
plt.scatter(car_price.enginesize,car_price.price)
plt.xlabel('enginesize')                          
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %% [markdown]
# <font color='red'>**The above plot shows that with increase in `wheelbase`, `carlength`, `carwidth`, `curbweight` and `enginesize`, `price` also increases. But there is no linear correlation between `carheight` and `price`.**</font>

# %%
# Plotting scatter plots

plt.figure(figsize=(20, 12))

plt.subplot(3,3,1)
plt.scatter(car_price.boreratio,car_price.price)
plt.xlabel('boreratio')                          
plt.ylabel('price') 

plt.subplot(3,3,2)
plt.scatter(car_price.stroke,car_price.price)
plt.xlabel('stroke')                          
plt.ylabel('price') 

plt.subplot(3,3,3)
plt.scatter(car_price.compressionratio,car_price.price)
plt.xlabel('compressionratio')                          
plt.ylabel('price') 

plt.subplot(3,3,4)
plt.scatter(car_price.horsepower,car_price.price)
plt.xlabel('horsepower')                          
plt.ylabel('price') 

plt.subplot(3,3,5)
plt.scatter(car_price.peakrpm,car_price.price)
plt.xlabel('peakrpm')                          
plt.ylabel('price') 

plt.subplot(3,3,6)
plt.scatter(car_price.citympg,car_price.price)
plt.xlabel('citympg')                          
plt.ylabel('price')

plt.subplot(3,3,7)
plt.scatter(car_price.highwaympg,car_price.price)
plt.xlabel('highwaympg')                          
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %% [markdown]
# <font color='red'>**The above plot shows that `boreratio`, `horsepower` have somewhat positive linear correlation with `price`. Also `citympg` and `highwaympg` have negative linear correlation with `price`. But `stroke`, `compressionratio` and `peakrpm` do not have linear correlation with `price`.**</font>

# %% [markdown]
# #### Visualising Categorical Variables
#
# Let's make a boxplot these variables.

# %%
plt.figure(figsize=(20, 12))
plt.subplot(2,3,1)
sns.boxplot(x = 'fueltype', y = 'price', data = car_price)
plt.subplot(2,3,2)
sns.boxplot(x = 'aspiration', y = 'price', data = car_price)
plt.subplot(2,3,3)
sns.boxplot(x = 'doornumber', y = 'price', data = car_price)
plt.subplot(2,3,4)
sns.boxplot(x = 'carbody', y = 'price', data = car_price)
plt.subplot(2,3,5)
sns.boxplot(x = 'drivewheel', y = 'price', data = car_price)
plt.subplot(2,3,6)
sns.boxplot(x = 'enginelocation', y = 'price', data = car_price)
plt.show()

# %% [markdown]
# <font color='red'>**The above plot shows following things.**</font>
#
#    1) price vs fueltype - diesel have higher price range as compared to gas
#
#    2) price vs aspiration - turbo have higher price range as compared to std
#
#    3) price vs doornumber - four doornumber cars have slightly higher price range as compared to two doornumber
#
#    4) price vs carbody - covertible and hardtop have higher price range as compared to others
#
#    5) price vs drivewheel - cars with rwd have higher price range as compared to others
#
#    6) price vs enginelocation - rear enginelocation have higher price range as compared to front enginelocation

# %%
plt.figure(figsize=(16, 10))

plt.subplot(2,2,1)
sns.boxplot(x = 'enginetype', y = 'price', data = car_price)
plt.subplot(2,2,2)
sns.boxplot(x = 'cylindernumber', y = 'price', data = car_price)
plt.subplot(2,2,3)
sns.boxplot(x = 'fuelsystem', y = 'price', data = car_price)

# %% [markdown]
# <font color='red'>**The above plot shows following things.**</font>
#
#    1) price vs enginetype - ohcv, l and dohc have higher price range as compared to others
#
#    2) price vs cylindernumber - with increase in cylinder numbers price also increases
#
#    3) price vs fuelsystem - mpfi and idi have higher price range as compared to others

# %% [markdown]
# ### <font color='blue'> Bivariate analysis:</font>

# %%
plt.figure(figsize = (10, 8))
sns.boxplot(x = 'fueltype', y = 'price', hue = 'aspiration', data = car_price)
plt.show()

# %% [markdown]
# <font color='red'>**The above plot shows that `turbo` aspiration has higher `price` in both i.e. `gas` and `diesel` fueltype cars than `std` aspiration type.**</font>

# %%
plt.figure(figsize = (10, 8))
sns.boxplot(x = 'drivewheel', y = 'price', hue = 'doornumber', data = car_price)
plt.show()

# %% [markdown]
# <font color='red'>**The above plot shows that in `rwd` and `fwd`, `four` doornumber cars have higher price and in `4wd`, `two` doornumber cars have higher price.**</font>

# %% [markdown]
# ## Step 3: Data Preparation

# %%
# Identifying numerical columns
num_cols = car_price._get_numeric_data().columns
num_cols
# Out:
# Index(['car_ID', 'symboling', 'wheelbase', 'carlength', 'carwidth',
#        'carheight', 'curbweight', 'enginesize', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
# Identifying categorical columns
cat_cols = car_price.select_dtypes(include=['O']).columns.values
cat_cols
# Out:
# array(['CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody',
#        'drivewheel', 'enginelocation', 'enginetype', 'cylindernumber',
#        'fuelsystem'], dtype=object)

# %% [markdown]
# <font color='red'>**From data visualisation it is clear that `car_ID`, `symboling`, `carheight`,`stroke`, `compressionratio`, `peakrpm` columns are irrelevant to our model.**</font>

# %%
# Deleting irrelevant columns
car_price.drop(['car_ID','symboling','carheight', 'stroke', 'compressionratio', 'peakrpm'], axis = 1, inplace = True)

# %% [markdown]
# There is a variable named CarName which is comprised of two parts - the first word is the name of 'car company' and the second is the 'car model'. For example, chevrolet impala has 'chevrolet' as the car company name and 'impala' as the car model name. We need to consider only company name as the independent variable for model building.

# %%
# Retaining only company name from CarName column

car_price['CarName'] = car_price['CarName'].apply(lambda x: x.split(' ')[0])

# Lets see unique values in column 'CarName'

print('List of unique values in column CarName are :\n\n', car_price['CarName'].unique())
print('\nTotal no. of unique values in column CarName are :',car_price['CarName'].nunique())
# Out:
# List of unique values in column CarName are :
#
#  ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'maxda' 'mazda' 'buick' 'mercury' 'mitsubishi' 'Nissan' 'nissan'
#  'peugeot' 'plymouth' 'porsche' 'porcshce' 'renault' 'saab' 'subaru'
#  'toyota' 'toyouta' 'vokswagen' 'volkswagen' 'vw' 'volvo']
#
# Total no. of unique values in column CarName are : 28

# %%
# Converting all names to lower case
car_price['CarName'] = car_price['CarName'].apply(lambda x: x.lower())

# Some company names are wrongly spelled
# Replacing 'maxda' to 'mazda', 'porcshce' to 'porsche','toyouta' to 'toyota' and 'vokswagen', 'vw' to 'volkswagen'

car_price['CarName'] = car_price['CarName'].replace({'maxda':'mazda'},regex=True)
car_price['CarName'] = car_price['CarName'].replace({'porcshce':'porsche'},regex=True)
car_price['CarName'] = car_price['CarName'].replace({'toyouta':'toyota'},regex=True)
car_price['CarName'] = car_price['CarName'].replace({'vokswagen':'volkswagen','vw':'volkswagen'},regex=True)

print('List of unique values in column CarName are :\n\n', car_price['CarName'].unique())
print('\nTotal no. of unique values in column CarName are :',car_price['CarName'].nunique())
# Out:
# List of unique values in column CarName are :
#
#  ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'mazda' 'buick' 'mercury' 'mitsubishi' 'nissan' 'peugeot' 'plymouth'
#  'porsche' 'renault' 'saab' 'subaru' 'toyota' 'volkswagen' 'volvo']
#
# Total no. of unique values in column CarName are : 22

# %% [markdown]
# ### Converting `categorical columns` into `numerical columns`

# %%
# Converting 'gas' to 0 and 'diesel' to 1 from 'fueltype' column
car_price['fueltype'] = car_price['fueltype'].replace({'gas':0,'diesel':1},regex=True)

# Converting 'std' to 0 and 'diesel' to 1 from 'aspiration' column
car_price['aspiration'] = car_price['aspiration'].replace({'std':0,'turbo':1},regex=True)

# Converting 'two' to 0 and 'four' to 1 from 'doornumber' column
car_price['doornumber'] = car_price['doornumber'].replace({'two':0,'four':1},regex=True)

# Converting 'front' to 0 and 'rear' to 1 from 'enginelocation' column
car_price['enginelocation'] = car_price['enginelocation'].replace({'front':0,'rear':1},regex=True)

# %% [markdown]
# ### Dummy Variables

# %%
# Get the dummy variables for the feature 'CarName' and store it in a new variable - 'company_name'
# and drop the first column from company_name df using 'drop_first = True'
company_name = pd.get_dummies(car_price['CarName'], drop_first = True)

# Add the results to the original car_price dataframe
car_price = pd.concat([car_price, company_name], axis = 1)

# Drop 'CarName' as we have created the dummies for it
car_price.drop(['CarName'], axis = 1, inplace = True)

# Using the same process to get the dummy variables for the features 'carbody', 'drivewheel', 'enginetype', 'fuelsystem' 
# and 'cylindernumber'.

Car_Body = pd.get_dummies(car_price['carbody'], drop_first = True)
car_price = pd.concat([car_price, Car_Body], axis = 1)
car_price.drop(['carbody'], axis = 1, inplace = True)

Drive_Wheel = pd.get_dummies(car_price['drivewheel'], drop_first = True)
car_price = pd.concat([car_price, Drive_Wheel], axis = 1)
car_price.drop(['drivewheel'], axis = 1, inplace = True)

Engine_Type = pd.get_dummies(car_price['enginetype'], drop_first = True)
car_price = pd.concat([car_price, Engine_Type], axis = 1)
car_price.drop(['enginetype'], axis = 1, inplace = True)

Fuel_System = pd.get_dummies(car_price['fuelsystem'], drop_first = True)
car_price = pd.concat([car_price, Fuel_System], axis = 1)
car_price.drop(['fuelsystem'], axis = 1, inplace = True)

Cylinder_Number = pd.get_dummies(car_price['cylindernumber'], drop_first = True)
car_price = pd.concat([car_price, Cylinder_Number], axis = 1)
car_price.drop(['cylindernumber'], axis = 1, inplace = True)

car_price.head()
# Out:
#    fueltype  aspiration  doornumber  enginelocation  wheelbase  carlength  \
# 0         0           0           0               0       88.6      168.8
# 1         0           0           0               0       88.6      168.8
# 2         0           0           0               0       94.5      171.2
# 3         0           0           1               0       99.8      176.6
# 4         0           0           1               0       99.4      176.6
#
#    carwidth  curbweight  enginesize  boreratio  ...  mfi  mpfi  spdi  spfi  \
# 0      64.1        2548         130       3.47  ...    0     1     0     0
# 1      64.1        2548         130       3.47  ...    0     1     0     0
# 2      65.5        2823         152       2.68  ...    0     1     0     0
# 3      66.2        2337         109       3.19  ...    0     1     0     0
# 4      66.4        2824         136       3.19  ...    0     1     0     0
#
#    five  four  six  three  twelve  two
# ...

# %% [markdown]
# ## Step 4: Splitting the Data into Training and Testing Sets

# %%
from sklearn.model_selection import train_test_split

# We specify this so that the train and test data set always have the same rows, respectively
np.random.seed(0)
cp_train, cp_test = train_test_split(car_price, train_size = 0.7, test_size = 0.3, random_state = 100)

# %%
cp_train.describe()
# Out:
#          fueltype  aspiration  doornumber  enginelocation   wheelbase  \
# count  143.000000  143.000000  143.000000      143.000000  143.000000
# mean     0.090909    0.181818    0.559441        0.006993   98.523077
# std      0.288490    0.387050    0.498199        0.083624    5.961835
# min      0.000000    0.000000    0.000000        0.000000   86.600000
# 25%      0.000000    0.000000    0.000000        0.000000   94.500000
# 50%      0.000000    0.000000    1.000000        0.000000   96.500000
# 75%      0.000000    0.000000    1.000000        0.000000  101.200000
# max      1.000000    1.000000    1.000000        1.000000  115.600000
#
#         carlength    carwidth   curbweight  enginesize   boreratio  ...  \
# count  143.000000  143.000000   143.000000  143.000000  143.000000  ...
# mean   173.416783   65.839860  2539.510490  124.958042    3.307413  ...
# std     12.598122    2.214203   544.650539   40.974034    0.260997  ...
# ...

# %% [markdown]
# ### Rescaling the Features
#
# We will use MinMax scaling.

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
# Apply scaler() to all the columns except the 'yes-no' and 'dummy' variables
num_vars = ['wheelbase', 'carlength', 'carwidth', 'curbweight','enginesize', 'boreratio',
            'horsepower', 'citympg', 'highwaympg', 'price']

cp_train[num_vars] = scaler.fit_transform(cp_train[num_vars])

# %%
cp_train.describe()
# Out:
#          fueltype  aspiration  doornumber  enginelocation   wheelbase  \
# count  143.000000  143.000000  143.000000      143.000000  143.000000
# mean     0.090909    0.181818    0.559441        0.006993    0.411141
# std      0.288490    0.387050    0.498199        0.083624    0.205581
# min      0.000000    0.000000    0.000000        0.000000    0.000000
# 25%      0.000000    0.000000    0.000000        0.000000    0.272414
# 50%      0.000000    0.000000    1.000000        0.000000    0.341379
# 75%      0.000000    0.000000    1.000000        0.000000    0.503448
# max      1.000000    1.000000    1.000000        1.000000    1.000000
#
#         carlength    carwidth  curbweight  enginesize   boreratio  ...    mfi  \
# count  143.000000  143.000000  143.000000  143.000000  143.000000  ...  143.0
# mean     0.525476    0.461655    0.407878    0.241351    0.497946  ...    0.0
# std      0.204848    0.184517    0.211269    0.154619    0.207140  ...    0.0
# ...

# %%
cp_train.shape
# Out:
# (143, 60)

# %% [markdown]
# ### Dividing into X and Y sets for the model building

# %%
y_train = cp_train.pop('price')
X_train = cp_train

# %% [markdown]
# ## Step 5: Building a linear model

# %% [markdown]
# ### RFE
# Recursive feature elimination

# %%
# Importing RFE and LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

# Running RFE with the output number of the variable equal to 16
lm = LinearRegression()
lm.fit(X_train, y_train)

rfe = RFE(lm, 16)             # running RFE
rfe = rfe.fit(X_train, y_train)

# %%
list(zip(X_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('fueltype', False, 36),
#  ('aspiration', False, 28),
#  ('doornumber', False, 43),
#  ('enginelocation', True, 1),
#  ('wheelbase', False, 11),
#  ('carlength', False, 10),
#  ('carwidth', True, 1),
#  ('curbweight', True, 1),
#  ('enginesize', False, 7),
#  ('boreratio', False, 3),
#  ('horsepower', True, 1),
#  ('citympg', False, 25),
#  ('highwaympg', True, 1),
#  ('audi', False, 9),
#  ('bmw', True, 1),
#  ('buick', True, 1),
#  ('chevrolet', False, 35),
#  ('dodge', False, 26),
#  ('honda', False, 19),
#  ('isuzu', False, 14),
#  ('jaguar', True, 1),
#  ('mazda', False, 44),
#  ('mercury', False, 39),
#  ('mitsubishi', False, 18),
#  ('nissan', False, 30),
#  ('peugeot', False, 15),
#  ('plymouth', False, 24),
#  ('porsche', True, 1),
#  ('renault', False, 29),
#  ('saab', False, 8),
#  ('subaru', False, 6),
#  ('toyota', False, 33),
#  ('volkswagen', False, 37),
#  ('volvo', False, 4),
#  ('hardtop', True, 1),
#  ('hatchback', True, 1),
#  ('sedan', True, 1),
# ...

# %%
col = X_train.columns[rfe.support_]
col
# Out:
# Index(['enginelocation', 'carwidth', 'curbweight', 'horsepower', 'highwaympg',
#        'bmw', 'buick', 'jaguar', 'porsche', 'hardtop', 'hatchback', 'sedan',
#        'wagon', 'dohcv', 'three', 'twelve'],
#       dtype='object')

# %%
X_train.columns[~rfe.support_]
# Out:
# Index(['fueltype', 'aspiration', 'doornumber', 'wheelbase', 'carlength',
#        'enginesize', 'boreratio', 'citympg', 'audi', 'chevrolet', 'dodge',
#        'honda', 'isuzu', 'mazda', 'mercury', 'mitsubishi', 'nissan', 'peugeot',
#        'plymouth', 'renault', 'saab', 'subaru', 'toyota', 'volkswagen',
#        'volvo', 'fwd', 'rwd', 'l', 'ohc', 'ohcf', 'ohcv', 'rotor', '2bbl',
#        '4bbl', 'idi', 'mfi', 'mpfi', 'spdi', 'spfi', 'five', 'four', 'six',
#        'two'],
#       dtype='object')

# %% [markdown]
# ### Building model using statsmodel, for the detailed statistics

# %%
# Creating X_train dataframe with RFE selected variables
X_train = X_train[col]

# %%
# Creating a function for building model

import statsmodels.api as sm  

def lr_model(b,a):
    a_const = sm.add_constant(a)
    lm = sm.OLS(b,a_const).fit()   # Running the linear model
    print(lm.summary())

# Deifining VIF funcion to calculate the VIFs for the new model

from statsmodels.stats.outliers_influence import variance_inflation_factor

def VIF(X):
    vif = pd.DataFrame()
    vif['Features'] = X.columns
    vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    vif['VIF'] = round(vif['VIF'], 2)
    vif = vif.sort_values(by = "VIF", ascending = False)
    return(vif)

# %%
#Creating a model

lr_model(y_train,X_train)
VIF(X_train)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.939
# Model:                            OLS   Adj. R-squared:                  0.931
# Method:                 Least Squares   F-statistic:                     120.7
# Date:                Mon, 06 Apr 2020   Prob (F-statistic):           3.01e-68
# Time:                        23:02:51   Log-Likelihood:                 216.63
# No. Observations:                 143   AIC:                            -399.3
# Df Residuals:                     126   BIC:                            -348.9
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.0654      0.044     -1.488      0.139      -0.152       0.022
# ...

# %% [markdown]
# <font color='red'>**Now from here onwards we are going to update the model by dropping variables which have p-value > 0.05 (Significance level) and vif > 5.**</font>

# %%
# Dropping the variable 'twelve' and updating the model

X_train_new = X_train.drop(["twelve"], axis = 1)
#Creating a model

lr_model(y_train,X_train_new)
VIF(X_train_new)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.938
# Model:                            OLS   Adj. R-squared:                  0.931
# Method:                 Least Squares   F-statistic:                     128.4
# Date:                Mon, 06 Apr 2020   Prob (F-statistic):           4.79e-69
# Time:                        23:03:10   Log-Likelihood:                 215.93
# No. Observations:                 143   AIC:                            -399.9
# Df Residuals:                     127   BIC:                            -352.5
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.0596      0.044     -1.365      0.175      -0.146       0.027
# ...

# %%
# Dropping the variable 'highwaympg' and updating the model

X_train_new = X_train_new.drop(["highwaympg"], axis = 1)
#Creating a model

lr_model(y_train,X_train_new)
VIF(X_train_new)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.938
# Model:                            OLS   Adj. R-squared:                  0.931
# Method:                 Least Squares   F-statistic:                     137.2
# Date:                Mon, 06 Apr 2020   Prob (F-statistic):           7.64e-70
# Time:                        23:03:28   Log-Likelihood:                 215.20
# No. Observations:                 143   AIC:                            -400.4
# Df Residuals:                     128   BIC:                            -356.0
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.0251      0.032     -0.795      0.428      -0.088       0.037
# ...

# %%
# Dropping the variable 'dohcv' and updating the model

X_train_new = X_train_new.drop(["dohcv"], axis = 1)

# Creating a model
lr_model(y_train,X_train_new)
VIF(X_train_new)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.937
# Model:                            OLS   Adj. R-squared:                  0.931
# Method:                 Least Squares   F-statistic:                     147.7
# Date:                Mon, 06 Apr 2020   Prob (F-statistic):           9.79e-71
# Time:                        23:03:42   Log-Likelihood:                 214.68
# No. Observations:                 143   AIC:                            -401.4
# Df Residuals:                     129   BIC:                            -359.9
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.0235      0.032     -0.745      0.457      -0.086       0.039
# ...

# %%
# Dropping the variable 'carwidth' and updating the model

X_train_new = X_train_new.drop(["carwidth"], axis = 1)

# Creating a model
lr_model(y_train,X_train_new)
VIF(X_train_new)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.924
# Model:                            OLS   Adj. R-squared:                  0.917
# Method:                 Least Squares   F-statistic:                     132.5
# Date:                Mon, 06 Apr 2020   Prob (F-statistic):           1.02e-66
# Time:                        23:04:00   Log-Likelihood:                 201.61
# No. Observations:                 143   AIC:                            -377.2
# Df Residuals:                     130   BIC:                            -338.7
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.0071      0.034     -0.207      0.837      -0.075       0.061
# ...

# %%
# Dropping the variable 'three' and updating the model

X_train_new = X_train_new.drop(["three"], axis = 1)

# Creating a model
lr_model(y_train,X_train_new)
VIF(X_train_new)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.923
# Model:                            OLS   Adj. R-squared:                  0.917
# Method:                 Least Squares   F-statistic:                     143.1
# Date:                Mon, 06 Apr 2020   Prob (F-statistic):           2.45e-67
# Time:                        23:04:17   Log-Likelihood:                 200.41
# No. Observations:                 143   AIC:                            -376.8
# Df Residuals:                     131   BIC:                            -341.3
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.0039      0.034     -0.115      0.909      -0.072       0.064
# ...

# %%
# Dropping the variable 'hardtop' and updating the model

X_train_new = X_train_new.drop(["hardtop"], axis = 1)

# Creating a model
lr_model(y_train,X_train_new)
VIF(X_train_new)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.922
# Model:                            OLS   Adj. R-squared:                  0.916
# Method:                 Least Squares   F-statistic:                     155.1
# Date:                Mon, 06 Apr 2020   Prob (F-statistic):           7.26e-68
# Time:                        23:04:35   Log-Likelihood:                 198.95
# No. Observations:                 143   AIC:                            -375.9
# Df Residuals:                     132   BIC:                            -343.3
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.0355      0.029     -1.235      0.219      -0.092       0.021
# ...

# %%
# Dropping the variable 'sedan' and updating the model

X_train_2 = X_train_new.drop(["sedan"], axis = 1)

# Creating a model
lr_model(y_train,X_train_2)
VIF(X_train_2)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.921
# Model:                            OLS   Adj. R-squared:                  0.915
# Method:                 Least Squares   F-statistic:                     171.4
# Date:                Mon, 06 Apr 2020   Prob (F-statistic):           1.16e-68
# Time:                        23:04:46   Log-Likelihood:                 198.11
# No. Observations:                 143   AIC:                            -376.2
# Df Residuals:                     133   BIC:                            -346.6
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.0659      0.015     -4.324      0.000      -0.096      -0.036
# ...

# %%
# Dropping the variable 'hatchback' and updating the model

X_train_2 = X_train_2.drop(["hatchback"], axis = 1)

# Creating a model
lr_model(y_train,X_train_2)
VIF(X_train_2)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.919
# Model:                            OLS   Adj. R-squared:                  0.914
# Method:                 Least Squares   F-statistic:                     189.3
# Date:                Mon, 06 Apr 2020   Prob (F-statistic):           4.00e-69
# Time:                        23:05:05   Log-Likelihood:                 196.39
# No. Observations:                 143   AIC:                            -374.8
# Df Residuals:                     134   BIC:                            -348.1
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.0802      0.013     -6.128      0.000      -0.106      -0.054
# ...

# %%
# Dropping the variable 'curbweight' and updating the model

X_train_2 = X_train_2.drop(["curbweight"], axis = 1)

# Creating a model
lr_model(y_train,X_train_2)
VIF(X_train_2)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.850
# Model:                            OLS   Adj. R-squared:                  0.842
# Method:                 Least Squares   F-statistic:                     109.1
# Date:                Mon, 06 Apr 2020   Prob (F-statistic):           2.19e-52
# Time:                        23:05:20   Log-Likelihood:                 152.47
# No. Observations:                 143   AIC:                            -288.9
# Df Residuals:                     135   BIC:                            -265.2
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.0090      0.014      0.664      0.508      -0.018       0.036
# ...

# %%
# Dropping the variable 'wagon' and updating the model

X_train_2 = X_train_2.drop(["wagon"], axis = 1)

# Creating a model
lr_model(y_train,X_train_2)
VIF(X_train_2)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.850
# Model:                            OLS   Adj. R-squared:                  0.843
# Method:                 Least Squares   F-statistic:                     128.0
# Date:                Mon, 06 Apr 2020   Prob (F-statistic):           1.98e-53
# Time:                        23:05:35   Log-Likelihood:                 152.40
# No. Observations:                 143   AIC:                            -290.8
# Df Residuals:                     136   BIC:                            -270.1
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.0102      0.013      0.771      0.442      -0.016       0.036
# ...

# %%
# Dropping the variable 'porsche' and updating the model

X_train_2 = X_train_2.drop(["porsche"], axis = 1)

# Creating a model
lr_model(y_train,X_train_2)
VIF(X_train_2)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.849
# Model:                            OLS   Adj. R-squared:                  0.843
# Method:                 Least Squares   F-statistic:                     153.8
# Date:                Mon, 06 Apr 2020   Prob (F-statistic):           2.20e-54
# Time:                        23:05:48   Log-Likelihood:                 152.01
# No. Observations:                 143   AIC:                            -292.0
# Df Residuals:                     137   BIC:                            -274.2
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.0070      0.013      0.553      0.581      -0.018       0.032
# ...

# %% [markdown]
# ### <font color='red'>So now all the variables have p-value less than 0.05(Significance level) and vif less than 5.</font>
# ### <font color='red'>So this is our final linear regression model.</font>

# %% [markdown]
# ## Step 7: Residual Analysis of the train data
#
# So, now to check if the error terms are also normally distributed (which is infact, one of the major assumptions of linear regression), let us plot the histogram of the error terms and see what it looks like.

# %%
X_train_lm = sm.add_constant(X_train_2)
lm = sm.OLS(y_train,X_train_lm).fit()   # Running the linear model
y_train_price = lm.predict(X_train_lm)

# %%
# Plot the histogram of the error terms
fig = plt.figure()
sns.distplot((y_train - y_train_price), bins = 20)
fig.suptitle('Error Terms', fontsize = 20)                  # Plot heading 
plt.xlabel('Errors', fontsize = 18)                         # X-label
# Out:
# Text(0.5, 0, 'Errors')

# %% [markdown]
# ## Step 8: Making Predictions Using the Final Model
#
# Now that we have fitted the model and checked the normality of error terms,
# it's time to go ahead and make predictions using the final model.

# %%
# Apply scaler() to all the columns except the 'yes-no' and 'dummy' variables
num_vars = ['wheelbase', 'carlength', 'carwidth', 'curbweight','enginesize', 'boreratio',
            'horsepower', 'citympg', 'highwaympg', 'price']

cp_test[num_vars] = scaler.transform(cp_test[num_vars])

# %% [markdown]
# #### Dividing into X_test and y_test

# %%
y_test = cp_test.pop('price')
X_test = cp_test

# %%
# Now let's use our model to make predictions.

# Creating X_test_new dataframe by dropping variables from X_test
X_test_new = X_test[X_train_2.columns]

# Adding a constant variable 
X_test_new_lm = sm.add_constant(X_test_new)

# Making predictions
y_pred = lm.predict(X_test_new_lm)

# %% [markdown]
# ## Step 9: Model Evaluation
#
# Let's now plot the graph for actual versus predicted values.

# %%
# Plotting y_test and y_pred to understand the spread.
fig = plt.figure()
plt.scatter(y_test,y_pred)
fig.suptitle('y_test vs y_pred', fontsize=20)              # Plot heading 
plt.xlabel('y_test', fontsize=18)                          # X-label
plt.ylabel('y_pred', fontsize=16)                          # Y-label
# Out:
# Text(0, 0.5, 'y_pred')

# %%
# Lets calculate the R-squared score on the test set.

from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.8798820751230386

# %% [markdown]
# <font color='red'>**So on test set we have r2_scrore of `0.88` which is good.**</font>
